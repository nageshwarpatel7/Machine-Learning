# %% [markdown]
# ### Diabetes Predictions

# %%
from sklearn.datasets import load_diabetes

# %%
dataset = load_diabetes()

# %%
print(dataset['DESCR'])
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
#     - s6      glu, blood sugar level
#
# Note: Each of these 10 feature variables have been mean centered and scaled by the standard deviation times the square root of `n_samples` (i.e. the sum of squares of each column totals 1).
#
# Source URL:
# https://www4.stat.ncsu.edu/~boos/var.select/diabetes.html
#
# For more information see:
# Bradley Efron, Trevor Hastie, Iain Johnstone and Robert Tibshirani (2004) "Least Angle Regression," Annals of Statistics (with discussion), 407-499.
# (https://web.stanford.edu/~hastie/Papers/LARS/LeastAngle_2002.pdf)

# %%
import pandas as pd
df_diabetes = pd.DataFrame(dataset.data,columns=["age",
    "sex","bmi",'bp','s1','s2','s3','s4','s5','s6'])

# %%
df_diabetes
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019907 -0.017646
# 1   -0.039493 -0.068332 -0.092204
# 2   -0.002592  0.002861 -0.025930
# 3    0.034309  0.022688 -0.009362
# 4   -0.002592 -0.031988 -0.046641
# ..        ...       ...       ...
# 437 -0.002592  0.031193  0.007207
# 438  0.034309 -0.018114  0.044485
# 439 -0.011080 -0.046883  0.015491
# 440  0.026560  0.044529 -0.025930
# 441 -0.039493 -0.004222  0.003064
#
# [442 rows x 10 columns]

# %%
## Independent features
X= df_diabetes
y = dataset['target']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test= train_test_split(X,y, train_size=0.3, random_state=10)

# %%
X_train
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 67   0.041708  0.050680 -0.014828 -0.017135 -0.005697  0.008394 -0.013948
# 96   0.056239  0.050680  0.009961  0.049415 -0.004321 -0.012274 -0.043401
# 22  -0.085430 -0.044642 -0.004050 -0.009113 -0.002945  0.007767  0.022869
# 254  0.030811  0.050680  0.056307  0.076958  0.049341 -0.012274 -0.036038
# 244 -0.060003  0.050680  0.054152 -0.019442 -0.049727 -0.048912  0.022869
# ..        ...       ...       ...       ...       ...       ...       ...
# 369 -0.009147 -0.044642  0.037984 -0.040099 -0.024960 -0.003819 -0.043401
# 320 -0.023677 -0.044642  0.030440 -0.005670  0.082364  0.092004 -0.017629
# 15  -0.052738  0.050680 -0.018062  0.080401  0.089244  0.107662 -0.039719
# 125 -0.005515  0.050680 -0.008362 -0.002228 -0.033216 -0.063630 -0.036038
# 265 -0.034575  0.050680 -0.025607 -0.017135  0.001183 -0.002880  0.008142
#
#            s4        s5        s6
# 67  -0.001854 -0.011897  0.003064
# 96   0.034309  0.060791  0.032059
# 22  -0.039493 -0.061176 -0.013504
# 254  0.071210  0.120051  0.090049
# 244 -0.039493 -0.043984 -0.005220
# ..        ...       ...       ...
# 369  0.015858 -0.005142  0.027917
# 320  0.071210  0.033043  0.003064
# 15   0.108111  0.036060 -0.042499
# 125 -0.002592  0.080590  0.007207
# 265 -0.015508  0.014821  0.040343
#
# [132 rows x 10 columns]

# %%
# correlation
X_train.corr()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# age  1.000000  0.223223  0.169166  0.415341  0.069851  0.023969 -0.193147
# sex  0.223223  1.000000  0.033295  0.336277 -0.028350  0.102396 -0.402874
# bmi  0.169166  0.033295  1.000000  0.323581  0.195534  0.218212 -0.391333
# bp   0.415341  0.336277  0.323581  1.000000  0.266142  0.235600 -0.356387
# s1   0.069851 -0.028350  0.195534  0.266142  1.000000  0.841221 -0.054698
# s2   0.023969  0.102396  0.218212  0.235600  0.841221  1.000000 -0.296227
# s3  -0.193147 -0.402874 -0.391333 -0.356387 -0.054698 -0.296227  1.000000
# s4   0.185710  0.288919  0.374658  0.360399  0.581211  0.673700 -0.768160
# s5   0.244635  0.104421  0.367747  0.424050  0.517207  0.200682 -0.421054
# s6   0.231763  0.133401  0.337848  0.339006  0.345120  0.260194 -0.298347
#
#            s4        s5        s6
# age  0.185710  0.244635  0.231763
# sex  0.288919  0.104421  0.133401
# bmi  0.374658  0.367747  0.337848
# bp   0.360399  0.424050  0.339006
# s1   0.581211  0.517207  0.345120
# s2   0.673700  0.200682  0.260194
# s3  -0.768160 -0.421054 -0.298347
# s4   1.000000  0.585374  0.412801
# s5   0.585374  1.000000  0.472934
# s6   0.412801  0.472934  1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(15,10))
sns.heatmap(X_train.corr(), annot=True)
# Out:
# <Axes: >

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor()

# %%
regressor.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# ### Hyperparameter tuning

# %%
param = {
    'criterion' :['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
    'splitter' :['best','random'],
    'max_depth' :[1,2,3,4,5,10,20,25],
    'max_features' : ['auto','sqrt','log2']
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
regressor = DecisionTreeRegressor()

# %%
grid = GridSearchCV(regressor,param_grid=param, scoring='neg_mean_squared_error',cv=5)

# %%
import warnings
warnings.filterwarnings('ignore')
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['squared_error', 'friedman_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_depth': [1, 2, 3, 4, 5, 10, 20, 25],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              scoring='neg_mean_squared_error')

# %%
grid.best_params_
# Out:
# {'criterion': 'friedman_mse',
#  'max_depth': 3,
#  'max_features': 'sqrt',
#  'splitter': 'best'}

# %%
y_pred = grid.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
print(r2_score(y_pred,y_test))
print(mean_absolute_error(y_pred,y_test))
print(mean_squared_error(y_pred,y_test))
# Out:
# -0.13679562286084823
# 48.551332700822265
# 3647.170204691924

# %%
selectmodel = DecisionTreeRegressor(criterion = 'friedman_mse',
 max_depth = 3,
 max_features ='sqrt',
 splitter = 'best')

# %%
selectmodel.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='friedman_mse', max_depth=3,
#                       max_features='sqrt')

# %%
## visualize the decision tree
from sklearn import tree
plt.figure(figsize=(10,15))
tree.plot_tree(selectmodel,filled=True)
# Out:
# [Text(0.5, 0.875, 'x[6] <= 0.003\nfriedman_mse = 6001.576\nsamples = 132\nvalue = 152.583'),
#  Text(0.25, 0.625, 'x[4] <= -0.03\nfriedman_mse = 5933.577\nsamples = 83\nvalue = 176.807'),
#  Text(0.375, 0.75, 'True  '),
#  Text(0.125, 0.375, 'x[1] <= 0.003\nfriedman_mse = 4968.987\nsamples = 20\nvalue = 130.25'),
#  Text(0.0625, 0.125, 'friedman_mse = 4718.24\nsamples = 5\nvalue = 207.4'),
#  Text(0.1875, 0.125, 'friedman_mse = 2407.182\nsamples = 15\nvalue = 104.533'),
#  Text(0.375, 0.375, 'x[2] <= 0.018\nfriedman_mse = 5333.227\nsamples = 63\nvalue = 191.587'),
#  Text(0.3125, 0.125, 'friedman_mse = 3543.026\nsamples = 28\nvalue = 155.214'),
#  Text(0.4375, 0.125, 'friedman_mse = 4860.273\nsamples = 35\nvalue = 220.686'),
#  Text(0.75, 0.625, 'x[9] <= 0.042\nfriedman_mse = 3439.145\nsamples = 49\nvalue = 111.551'),
#  Text(0.625, 0.75, '  False'),
#  Text(0.625, 0.375, 'x[0] <= -0.04\nfriedman_mse = 2835.945\nsamples = 43\nvalue = 104.093'),
#  Text(0.5625, 0.125, 'friedman_mse = 4060.145\nsamples = 17\nvalue = 127.824'),
#  Text(0.6875, 0.125, 'friedman_mse = 1426.552\nsamples = 26\nvalue = 88.577'),
#  Text(0.875, 0.375, 'x[0] <= 0.018\nfriedman_mse = 4506.667\nsamples = 6\nvalue = 165.0'),
#  Text(0.8125, 0.125, 'friedman_mse = 424.667\nsamples = 3\nvalue = 108.0'),
#  Text(0.9375, 0.125, 'friedman_mse = 2090.667\nsamples = 3\nvalue = 222.0')]
